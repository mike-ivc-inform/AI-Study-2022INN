# %% [markdown]
# **Личные данные**
#
# * Имя и Фамилия:
# * Ваш telegram allias для связи:
# * Имя вашего ментора:

# %% [markdown]
# **Добро пожаловать в проект!**
#
# В этом проекте вы будете использовать датасет "Netflix Movies and TV Shows".
#
# Датасет вкключает в себя следующие данные:
# * **show_id** - уникальный номер шоу на Нетфликс,
# * **type** - тип шоу: сериал или полнометражный фильм,
# * **title** - название шоу,
# * **director** - имя режиссера шоу,
# * **cast** - актеры и актеры озвучки, принимавшие участие в шоу,
# * **country** - страна, в которой шоу было снято/произведено,
# * **data_added** - дата появления шоу на Нетфликс,
# * **release_year** - дата первого появления шоу на экранах вообще,
# * **rating** - возрастной рейтинг шоу,
# * **duration** - продолжительность шоу: в сезонах для сериалов, в минутах для фильмов
# * **listed_in** - к каким жанрам относится шоу
# * **description** - текстовое описание к шоу
#
# **Чему посвящен проект?**
#
# Выполняя проект вы можете использовать любые библиотеки. Основные задачи, которые вам придется решить следующие задачи:
# * визуализация данных,
# * обработка явных и неявных пропусков,
# * исследовательский анализ данных
# * применение классических алгоритмов машинного обучения;
#
# **Важно!!!**
#
# * Перед началом выполнения проекта не забудьте заполнить карточку вверху с личной информацией, чтобы менторы могли связаться с вами при необходимости.
# * Формат ответа: **Jupyter Notebook (ipynb)**.
# * Файл должен называться следующим образом **имя_фамилия_netflix_project.ipynb**
# * В комментариях с ячейками кода указываются шаги, которые вам необходимо выполнить.
# * Используйте Markdown для ответов на вопросы.
# * Активно комментируйте ваш код. Описывайте ход действий.

# %% [markdown]
# ---

# %% [markdown]
# **Реализация проекта ниже**

# %%
'''
- Импортируйте библиотеку Pandas. Сохраните ваш датасет как DataFrame под именем netflix_titles
'''

# %%
'''
- Выведите на экран первые 5 и последние 5 элементов вашего DataFrame
- Выведите общую информацию о вашем DataFrame
- Опишите датасет. Какие потенциальные проблемы вы в нем видите?
'''

# %%
'''
- Выведите общее количество строк в датасете
- Выведите соотношение фильмов и сериалов в датасете. Чего больше?
- Выведите на экран 10 режиссеров с наибольшим количеством работ на Нетфлиск. 
'''

# %%
'''
- В столбцах cast и director имеются пропущенные значения. Подсчитайте количество пропусков.
- По какой причине могли возникнуть эти пропуски?
- Заполните пропущенные значения в столбцах cast и director строкой "unknown".
- Проанлизируйте прочие столбцы на наличие пропусков.
'''

# %%
'''
- Оцените датасет на наличие явных дубликатов.
- Если в датасете имеются явные дубликаты, удалите их.
'''

# %%
'''
- Сколько сезонов обычно длится сериал на Нетфликс? Ответьте на вопрос с помощью круговой диаграммы.
- Используя столбатую диаграмму, визуализируйте 3 самые частые возрастные категории шоу на Нефтликс относительно общего количества шоу на Нетфликс.
- Используйте столбчатую диаграмму. Визуализируйте количество появившихся на Нетфликс шоу в разные годы
'''

# %%
'''
- Создайте новый DataFrame под названием movies_only
- Включите в него столбцы show_id, director, country, duration, release_year, rating, listed_in, description
- В DataFrame movies_only должны войти только фильмы, сериалы не должны входить в этот DataFrame
'''

# %%
'''
- Создайте столбце duration_category в новом DataFrame
- Использую данные из столбца Duration заполните столбец duration_category категориальными данными по продолжительности. Используйте следующие категории:
    - 0-30 минут
    - 31-60 минут
    - 61-90 минут
    - 91-120 минут
    - 121 и более минут
- Используйте столбчатую диаграмму. Оцените количество фильмов по столбцу duration_category
'''

# %%
'''
- Напишите общие выводы о проделанной работе. Что вы можете рассказать о полученном датасете на основе проведенного анализа?
'''

# %%
'''
ДОПОЛНИТЕЛЬНОЕ ЗАДАНИЕ. НЕ ОЦЕНИВАЕТСЯ. ВЫПОЛНЯЕТСЯ ПО ЖЕЛАНИЮ.

- Используйте DataFrame под названием movies_only.
- Реализуйте алгоритм классификации по собственному выбору. Объясните свой выбор.
- Попытайтесь предсказать значение в столбце duration_category на основе значений в столбцах direcotr, country, release_year, rating, listed_in, description 
(ПОДСКАЗКА: будет удобнее привести стобцы к категориальным данным)
- Получилось ли у вас? Если не получилось, объясните возможные причины, почему построить подобную модель невозможно?
'''
